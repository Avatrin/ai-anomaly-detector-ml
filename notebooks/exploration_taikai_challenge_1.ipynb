# %%
import os, json
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp "drive/MyDrive/Transfer.zip" .

# %%
# !unzip "drive/MyDrive/Transfer.zip"
# Out:
# Archive:  drive/MyDrive/Transfer.zip
#  extracting: Auto Bild 3.trace.csv
#  extracting: Auto Bild 3.trace

# %%
data = pd.read_csv("Auto Bild 3.trace.csv")

# %%
data.info
# Out:
# <bound method DataFrame.info of                                             [key]; [value]
# 0                                      Version; 0x03050000
# 1                            Name; Application.TraceDrives
# 2                             ApplicationName; Application
# 3        ApplicationDataGuid; 00000000-0000-0000-0000-0...
# 4                                IecTaskName; TaskHighPrio
# ...                                                    ...
# 1800261                                  ; 518479862; 0.17
# 1800262                                 ; 518484870; 0.155
# 1800263                                 ; 518489864; 0.195
# 1800264                                 ; 518494859; 0.211
# 1800265                                 ; 518499863; 0.245
#
# [1800266 rows x 1 columns]>

# %%
data[["var", "key", "value"]] = data["[key]; [value]"].str.split(';', expand=True)

# %%
df_split = data.drop(columns="[key]; [value]")

# %%
df_split
# Out:
#                          var                                    key   value
# 0                    Version                             0x03050000    None
# 1                       Name                Application.TraceDrives    None
# 2            ApplicationName                            Application    None
# 3        ApplicationDataGuid   00000000-0000-0000-0000-000000000000    None
# 4                IecTaskName                           TaskHighPrio    None
# ...                      ...                                    ...     ...
# 1800261                                                   518479862    0.17
# 1800262                                                   518484870   0.155
# 1800263                                                   518489864   0.195
# 1800264                                                   518494859   0.211
# 1800265                                                   518499863   0.245
#
# [1800266 rows x 3 columns]

# %% [markdown]
# # Isolation of non usable data

# %%
df_split["var"].notnull().sum()
# Out:
# 1800266

# %%
df_split[0:29]
# Out:
#                      var  ...    value
# 0                Version  ...     None
# 1                   Name  ...     None
# 2        ApplicationName  ...     None
# 3    ApplicationDataGuid  ...     None
# 4            IecTaskName  ...     None
# 5                Comment  ...     None
# 6          Trigger.Flags  ...     None
# 7         Condition.Name  ...     None
# 8    Condition.AddrFlags  ...     None
# 9        Condition.Class  ...     None
# 10        Condition.Size  ...     None
# 11          EveryNCycles  ...     None
# 12         BufferEntries  ...     None
# 13                 Flags  ...     None
# 14            0.Variable  ...     None
# 15   0.Address.AddrFlags  ...     None
# 16               0.Class  ...     None
# 17                0.Size  ...     None
# 18          0.GraphColor  ...     None
# 19           0.GraphType  ...     None
# 20     0.MinWarningColor  ...     None
# 21     0.MaxWarningColor  ...     None
# 22  0.CriticalLowerLimit  ...     None
# ...
